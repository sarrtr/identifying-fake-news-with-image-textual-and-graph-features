# %% [markdown]
# Link to the dataset: https://zenodo.org/records/11186584

# %% [markdown]
# **TRAIN DATA**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pd.read_csv("/content/train.csv")
train_df.head(5)
# Out:
#        id         fake_id        author  \
# 0  8wyqir             NaN   Corey_Lahey
# 1  88kzjb  DL_fake_88kzjb    BestGreene
# 2  29gcsn             NaN       pichuik
# 3  4hnu2b  GL_fake_4hnu2b     tom_toast
# 4  5vuecv  DL_fake_5vuecv  gaspitsjesse
#
#                                     original_caption  \
# 0                    snowmobile in rainbow six siege
# 1                              lines degrees of self
# 2  costa rica teams reaction after last penalty kick
# 3  these people in marvel themed wearable sleepin...
# 4  sad clown is sad give him a buck or two to che...
#
#                                    generated_caption  num_comments  \
# 0                                                NaN           0.0
# 1  a black and white photo of a wall with a shado...           7.0
# 2                                                NaN           2.0
# 3  dressed in costumes of different colors and sizes           3.0
# 4  a close up of a purse on a table with a lace d...           0.0
#
#    6_way_label  pristine_image  generated_image  real_text  fakenews_text  \
# 0            2               1                0          0              1
# 1            1               0                1          0              1
# 2            0               1                0          1              0
# 3            0               0                1          1              0
# 4            2               0                1          0              1
#
#    class
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1

# %%
train_df.shape
# Out:
# (385871, 12)

# %%
for col in train_df.columns:
  print(f"  {col}: {train_df[col].dtype}")
# Out:
#   id: object
#   fake_id: object
#   author: object
#   original_caption: object
#   generated_caption: object
#   num_comments: float64
#   6_way_label: int64
#   pristine_image: int64
#   generated_image: int64
#   real_text: int64
#   fakenews_text: int64
#   class: int64

# %%
missing = train_df.isnull().sum()
missing
# Out:
# id                        0
# fake_id              192935
# author                17940
# original_caption          0
# generated_caption    192935
# num_comments              0
# 6_way_label               0
# pristine_image            0
# generated_image           0
# real_text                 0
# fakenews_text             0
# class                     0
# dtype: int64

# %%
numeric_cols = train_df.select_dtypes(include=[np.number]).columns

if len(numeric_cols) > 0:
  print('Numeric columns:\n')
  print(train_df[numeric_cols].describe().round(2))

print('='*50)

categorical_cols = train_df.select_dtypes(include=['object']).columns
if len(categorical_cols) > 0:
  print('Categorical columns:\n')
  for col in categorical_cols:
      print(f"Column '{col}':")
      print(f"Unique values: {train_df[col].nunique()}")
      print(train_df[col].value_counts().head())
      print('\n')
# Out:
# Numeric columns:
#
#        num_comments  6_way_label  pristine_image  generated_image  real_text  \
# count     385871.00    385871.00        385871.0         385871.0  385871.00
# mean          20.26         0.99             0.5              0.5       0.56
# std          140.56         1.35             0.5              0.5       0.50
# min            0.00         0.00             0.0              0.0       0.00
# 25%            1.00         0.00             0.0              0.0       0.00
# 50%            2.00         0.00             0.0              1.0       1.00
# 75%            7.00         2.00             1.0              1.0       1.00
# max        10783.00         5.00             1.0              1.0       1.00
#
#        fakenews_text     class
# count      385871.00  385871.0
# mean            0.44       0.5
# std             0.50       0.5
# min             0.00       0.0
# 25%             0.00       0.0
# 50%             0.00       1.0
# 75%             1.00       1.0
# max             1.00       1.0
# ==================================================
# Categorical columns:
#
# Column 'id':
# Unique values: 385871
# id
# dclo02    1
# 8wyqir    1
# 88kzjb    1
# 29gcsn    1
# 4hnu2b    1
# Name: count, dtype: int64
#
#
# Column 'fake_id':
# Unique values: 192936
# fake_id
# SD_fake_5wsaaq    1
# DL_fake_88kzjb    1
# GL_fake_4hnu2b    1
# DL_fake_5vuecv    1
# DL_fake_cy92ab    1
# Name: count, dtype: int64
#
#
# Column 'author':
# Unique values: 207283
# author
# all-top-today_SS    3707
# dwaxe               2463
# Sariel007           1649
# flappytowel          880
# aresef               822
# Name: count, dtype: int64
#
#
# Column 'original_caption':
# Unique values: 377547
# original_caption
# d          159
# o          120
# oo          54
# hmmm        53
# feed me     31
# Name: count, dtype: int64
#
#
# Column 'generated_caption':
# Unique values: 172114
# generated_caption
# image of a man in a suit and tie speaking into a microphone    118
# a close up of a man in a suit and tie                           84
# man in a suit and tie speaking into a microphone                77
# image of a man in a suit and tie giving a speech                73
# image of a man in a suit and tie sitting at a table             71
# Name: count, dtype: int64

# %%
if len(numeric_cols) > 1:
    corr_matrix = train_df[numeric_cols].corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
    plt.title(f'Correlation matrix')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **VALIDATION DATA**

# %%
val_df = pd.read_csv("/content/validation.csv")
val_df.head(5)
# Out:
#        id         fake_id            author  \
# 0  8bqbfs  DL_fake_8bqbfs            rmw156
# 1  46euo5             NaN        CalumSyers
# 2  7n7rum             NaN  all-top-today_SS
# 3  5t6ht9             NaN       YtseThunder
# 4  bqqrx3  GL_fake_bqqrx3       FloopyDoopy
#
#                                     original_caption  \
# 0                                             hi pup
# 1                       this cat with its tongue out
# 2  til that billion light years away there is a m...
# 3        mark zuckerberg testing prototype vr gloves
# 4  how the danske bank money laundering scheme in...
#
#                                    generated_caption  num_comments  \
# 0  there is a television sitting on a table in a ...           1.0
# 1                                                NaN           6.0
# 2                                                NaN          20.0
# 3                                                NaN           4.0
# 4  a close up of a building with columns and a si...           2.0
#
#    6_way_label  pristine_image  generated_image  real_text  fakenews_text  \
# 0            2               0                1          0              1
# 1            0               1                0          1              0
# 2            3               1                0          0              1
# 3            0               1                0          1              0
# 4            0               0                1          1              0
#
#    class
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1

# %%
val_df.shape
# Out:
# (40909, 12)

# %%
for col in val_df.columns:
  print(f"  {col}: {val_df[col].dtype}")
# Out:
#   id: object
#   fake_id: object
#   author: object
#   original_caption: object
#   generated_caption: object
#   num_comments: float64
#   6_way_label: int64
#   pristine_image: int64
#   generated_image: int64
#   real_text: int64
#   fakenews_text: int64
#   class: int64

# %%
missing = val_df.isnull().sum()
missing
# Out:
# id                       0
# fake_id              20455
# author                1981
# original_caption         0
# generated_caption    20455
# num_comments             0
# 6_way_label              0
# pristine_image           0
# generated_image          0
# real_text                0
# fakenews_text            0
# class                    0
# dtype: int64

# %%
numeric_cols = val_df.select_dtypes(include=[np.number]).columns

if len(numeric_cols) > 0:
  print('Numeric columns:\n')
  print(val_df[numeric_cols].describe().round(2))

print('='*50)

categorical_cols = val_df.select_dtypes(include=['object']).columns
if len(categorical_cols) > 0:
  print('Categorical columns:\n')
  for col in categorical_cols:
      print(f"Column '{col}':")
      print(f"Unique values: {val_df[col].nunique()}")
      print(val_df[col].value_counts().head())
      print('\n')
# Out:
# Numeric columns:
#
#        num_comments  6_way_label  pristine_image  generated_image  real_text  \
# count      40909.00     40909.00         40909.0          40909.0   40909.00
# mean          20.80         0.98             0.5              0.5       0.56
# std          143.65         1.34             0.5              0.5       0.50
# min            0.00         0.00             0.0              0.0       0.00
# 25%            1.00         0.00             0.0              0.0       0.00
# 50%            2.00         0.00             1.0              0.0       1.00
# 75%            7.00         2.00             1.0              1.0       1.00
# max         7042.00         5.00             1.0              1.0       1.00
#
#        fakenews_text    class
# count       40909.00  40909.0
# mean            0.44      0.5
# std             0.50      0.5
# min             0.00      0.0
# 25%             0.00      0.0
# 50%             0.00      0.0
# 75%             1.00      1.0
# max             1.00      1.0
# ==================================================
# Categorical columns:
#
# Column 'id':
# Unique values: 40909
# id
# 5jsp8z    1
# 8bqbfs    1
# 46euo5    1
# 7n7rum    1
# 5t6ht9    1
# Name: count, dtype: int64
#
#
# Column 'fake_id':
# Unique values: 20454
# fake_id
# DL_fake_5jsp8z    1
# DL_fake_8bqbfs    1
# GL_fake_bqqrx3    1
# GL_fake_bcy65z    1
# GL_fake_15jomw    1
# Name: count, dtype: int64
#
#
# Column 'author':
# Unique values: 30356
# author
# all-top-today_SS    383
# dwaxe               306
# Sariel007           177
# aresef               94
# michaelconfoy        90
# Name: count, dtype: int64
#
#
# Column 'original_caption':
# Unique values: 40681
# original_caption
# d                        21
# o                         8
# avengers infinity war     6
# cat standing up           6
# oo                        5
# Name: count, dtype: int64
#
#
# Column 'generated_caption':
# Unique values: 19701
# generated_caption
# yahoo logo on a purple background                               19
# the washington post logo with a statue of abraham lincoln       15
# a white and gray logo for a new business                        14
# a close up of a clock with a circle of squares in the middle    14
# image of a man in a suit and tie speaking into a microphone     13
# Name: count, dtype: int64

# %%
if len(numeric_cols) > 1:
    corr_matrix = val_df[numeric_cols].corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
    plt.title(f'Correlation matrix')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **TEST DATA**

# %%
test_df = pd.read_csv("/content/test.csv")
test_df.head(5)
# Out:
#                id                                   original_caption  \
# 0          2kkorv  this rock formation i found in a cave looks li...
# 1  DL_fake_b5o9ed                            this curled up cucumber
# 2  DL_fake_4oagql                        boy trying to catch frisbee
# 3  SD_fake_399kkl  christian minister plans to mark muslim festiv...
# 4          3h845h                                          ninja kid
#
#                                    generated_caption  6_way_label  \
# 0                                                NaN            2
# 1  there is a cucumber that is sitting on a glass...            0
# 2  there is a man in an orange shirt playing fris...            0
# 3        man in a suit and tie smiling for a picture            0
# 4                                                NaN            0
#
#    pristine_image  generated_image  real_text  fakenews_text  class
# 0               1                0          0              1      0
# 1               0                1          1              0      1
# 2               0                1          1              0      1
# 3               0                1          1              0      1
# 4               1                0          1              0      0

# %%
test_df.shape
# Out:
# (83134, 9)

# %%
for col in test_df.columns:
  print(f"  {col}: {test_df[col].dtype}")
# Out:
#   id: object
#   original_caption: object
#   generated_caption: object
#   6_way_label: int64
#   pristine_image: int64
#   generated_image: int64
#   real_text: int64
#   fakenews_text: int64
#   class: int64

# %%
missing = test_df.isnull().sum()
missing
# Out:
# id                       0
# original_caption         0
# generated_caption    41567
# 6_way_label              0
# pristine_image           0
# generated_image          0
# real_text                0
# fakenews_text            0
# class                    0
# dtype: int64

# %%
numeric_cols = test_df.select_dtypes(include=[np.number]).columns

if len(numeric_cols) > 0:
  print('Numeric columns:\n')
  print(test_df[numeric_cols].describe().round(2))

print('='*50)

categorical_cols = test_df.select_dtypes(include=['object']).columns
if len(categorical_cols) > 0:
  print('Categorical columns:\n')
  for col in categorical_cols:
      print(f"Column '{col}':")
      print(f"Unique values: {test_df[col].nunique()}")
      print(test_df[col].value_counts().head())
      print('\n')
# Out:
# Numeric columns:
#
#        6_way_label  pristine_image  generated_image  real_text  fakenews_text  \
# count     83134.00         83134.0          83134.0   83134.00       83134.00
# mean          0.99             0.5              0.5       0.56           0.44
# std           1.35             0.5              0.5       0.50           0.50
# min           0.00             0.0              0.0       0.00           0.00
# 25%           0.00             0.0              0.0       0.00           0.00
# 50%           0.00             0.5              0.5       1.00           0.00
# 75%           2.00             1.0              1.0       1.00           1.00
# max           5.00             1.0              1.0       1.00           1.00
#
#          class
# count  83134.0
# mean       0.5
# std        0.5
# min        0.0
# 25%        0.0
# 50%        0.5
# 75%        1.0
# max        1.0
# ==================================================
# Categorical columns:
#
# Column 'id':
# Unique values: 83134
# id
# dheure            1
# 2kkorv            1
# DL_fake_b5o9ed    1
# DL_fake_4oagql    1
# SD_fake_399kkl    1
# Name: count, dtype: int64
#
#
# Column 'original_caption':
# Unique values: 41333
# original_caption
# d              38
# o              20
# oo             18
# nom nom nom    10
# circa          10
# Name: count, dtype: int64
#
#
# Column 'generated_caption':
# Unique values: 39137
# generated_caption
# yahoo logo on a purple background                               52
# a white and gray logo for a new business                        34
# a black and white photo of a u with a baseball bat              30
# man in a suit and tie speaking into a microphone                25
# a close up of a clock with a circle of squares in the middle    23
# Name: count, dtype: int64

# %%
if len(numeric_cols) > 1:
    corr_matrix = test_df[numeric_cols].corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
    plt.title(f'Correlation matrix')
    plt.tight_layout()
    plt.show()
